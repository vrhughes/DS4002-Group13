# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS4002-Group13/blob/main/twitterccdata_vh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cloning Git Location
! git clone https://github.com/vrhughes/DS4002-Group13
# Out:
# Cloning into 'DS4002-Group13'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 32 (delta 6), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 5.01 MiB | 9.66 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
# Reading In The Data
data = pd.read_csv('/content/DS4002-Group13/Project 1/twitter_sentiment_data.csv')
data.head()

# data is a DataFrame (43943, 3)
# in the sentiment column 1 is pro/believes, -1 is anti/non-believer, 0 is neutral
# Out:
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#               tweetid
# 0  792927353886371840
# 1  793124211518832641
# 2  793124402388832256
# 3  793124635873275904
# 4  793125156185137153

# %%
# Basic Cleaning Of "data"

# 1. Deleting tweetid column
data.drop(['tweetid'], axis = 1, inplace = True)
print("Dropped tweetid column")
print(data.head())

# 2. Getting rid of sentiment rows with value of 2(they're news sites not users)
data = data.drop(data[data['sentiment'] == 2].index)
print("Dropped sentiment rows with value of 2")
print(data.head())

# data is still a DataFrame, new dimensions (34667, 2)
# Out:
# Dropped tweetid column
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
# Dropped sentiment rows with value of 2
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...

# %%
# Finding Most Frequently Used Words
import nltk
nltk.download('punkt_tab')

data_exp = data.copy()

data_exp['tokenized_tweet'] = data_exp['message'].apply(nltk.word_tokenize)
data_exp.head()

# the tokenized_tweet column contains series of tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...
#
#                                      tokenized_tweet
# 0  [@, tiniebeany, climate, change, is, an, inter...
# 1  [RT, @, NatGeoChannel, :, Watch, #, BeforeTheF...
# 2  [Fabulous, !, Leonardo, #, DiCaprio, 's, film,...
# 3  [RT, @, Mick_Fanning, :, Just, watched, this, ...
# 5  [Unamshow, awache, kujinga, na, iko, global, w...

# %%
#
from collections import Counter
from nltk.corpus import stopwords
import string

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)

stop_words.update(list(string.punctuation))
print(stop_words)

tw_stopwords = ['rt', 'https', "'", "'s", "n't", "...", "…", 'http', "’", 'amp', 'would', 'one', 'q', 'you', 'make']
incl_stop = stop_words.union(tw_stopwords)

excl_stop = {'against', "isn't", 'doesn', "don't", "shouldn't"}
new_stop = set([word for word in incl_stop if word not in excl_stop])

print(new_stop)
# Out:
# {'up', 'so', 'she', 'own', 'are', 'doesn', 'needn', 'few', 'of', "you'll", 'other', 'we', "you're", "hadn't", 'wouldn', 'been', "it's", 're', "mustn't", 'him', 'because', 'had', "you've", 'these', 'won', 'her', 'have', 'a', 'shan', 'who', 'for', 'in', 'once', 'o', 'herself', 'aren', 'did', 'above', 'how', "didn't", 'from', 'was', 'all', 'does', 'each', 'haven', 'my', 'itself', 'if', 'ain', "you'd", 'before', 'while', 'himself', 'as', 'that', 'm', 'your', 'weren', 'what', 'when', 'its', 'theirs', 'couldn', 'having', "mightn't", 'there', "shan't", 'and', 'where', 'didn', 'can', 've', 'he', 'our', 'ours', 'wasn', 'being', 'just', 'or', 'hadn', 'themselves', 'them', "couldn't", 's', 'is', 'shouldn', 'very', 'this', 'were', 'me', 'off', 'the', 'nor', 'they', 'both', 'isn', "doesn't", 'ourselves', 'yours', 'some', 'same', 'their', 'do', 'during', 'mightn', 'here', 'over', 'y', 'against', 't', 'between', "weren't", "haven't", 'you', 'again', 'further', 'at', 'to', 'then', "she's", 'myself', 'yourself', 'be', 'any', 'which', 'why', 'too', 'mustn', 'on', 'should', "won't", "don't", 'after', 'don', 'hasn', 'but', "hasn't", 'such', 'only', 'until', 'whom', 'through', 'hers', 'by', "should've", 'below', 'with', 'out', 'd', 'into', 'will', 'an', 'under', 'i', 'll', "that'll", "needn't", 'than', 'more', 'most', "aren't", 'about', "wouldn't", 'no', 'down', 'now', 'yourselves', 'his', 'doing', 'it', "wasn't", "isn't", "shouldn't", 'ma', 'not', 'am', 'those', 'has'}
# {'(', '^', 'up', 'so', 'she', 'own', 'are', 'doesn', 'needn', 'few', 'of', "you'll", 'other', 'we', "you're", '<', "hadn't", 'wouldn', 'been', "it's", 're', "mustn't", 'him', '`', 'because', 'had', "you've", 'these', 'won', 'her', 'have', 'a', 'shan', 'who', 'for', 'in', 'once', 'o', 'herself', "'", 'aren', 'did', 'above', 'how', "didn't", 'from', 'was', 'all', 'does', 'each', 'haven', 'my', 'itself', 'if', 'ain', "you'd", 'before', 'while', 'himself', 'as', '.', 'that', 'm', 'your', 'weren', ')', 'what', 'when', 'its', '/', '@', 'theirs', 'couldn', 'having', "mightn't", 'there', "shan't", 'and', 'where', 'didn', 'can', 've', '#', 'he', 'our', 'ours', 'wasn', 'being', 'just', 'or', 'hadn', '!', 'themselves', '[', 'them', "couldn't", 's', 'is', 'shouldn', 'very', 'this', 'were', '+', 'me', 'off', '&', '}', 'the', 'nor', 'they', 'both', 'isn', "doesn't", 'ourselves', 'yours', 'some', 'same', 'their', 'do', 'during', 'mightn', 'here', 'over', 'y', '$', 'against', '{', 't', 'between', "weren't", "haven't", 'you', 'again', 'further', 'at', 'to', 'then', "she's", '%', '>', 'myself', 'yourself', 'be', '"', 'any', 'which', 'why', '|', '~', 'too', 'mustn', '=', 'on', 'should', '-', "won't", ',', "don't", '*', 'after', 'don', 'hasn', 'but', "hasn't", 'such', '\\', 'only', 'until', 'whom', 'through', ':', '_', 'hers', 'by', "should've", 'below', 'with', 'out', 'd', 'into', 'will', 'an', 'under', 'i', ']', 'll', ';', "that'll", "needn't", 'than', 'more', 'most', "aren't", 'about', '?', "wouldn't", 'no', 'down', 'now', 'yourselves', 'his', 'doing', 'it', "wasn't", "isn't", "shouldn't", 'ma', 'not', 'am', 'those', 'has'}
# {'(', '^', 'up', 'so', 'she', 'own', 'are', 'needn', 'other', 'few', 'of', "you'll", 'we', "you're", '<', "hadn't", 'wouldn', 'been', "it's", 're', "mustn't", 'him', '`', '…', 'because', 'had', "you've", 'these', 'won', 'her', 'have', 'a', 'shan', 'who', 'for', 'in', 'once', 'o', 'herself', "'", 'aren', 'did', 'above', 'how', "didn't", 'from', "n't", 'was', 'all', 'does', 'each', 'haven', 'my', 'would', 'itself', 'if', 'ain', 'before', "you'd", 'while', 'himself', 'as', '.', '’', 'that', 'm', 'your', 'weren', ')', 'what', 'when', 'its', '/', '@', 'theirs', 'couldn', 'having', "mightn't", 'there', "shan't", 'and', 'where', 'make', 'didn', 'can', 've', '#', 'he', 'our', 'one', 'ours', 'wasn', 'being', 'just', 'or', 'hadn', '!', 'themselves', '[', 'https', 'them', "couldn't", 's', 'is', 'shouldn', 'very', 'this', 'were', '+', 'me', 'off', '&', '}', 'the', 'nor', 'they', 'both', 'isn', "doesn't", 'ourselves', 'yours', 'some', 'same', 'their', 'am', 'do', 'during', 'mightn', 'here', 'over', 'y', '$', '{', 't', 'between', "weren't", "haven't", 'you', 'again', 'further', 'at', 'to', 'then', "she's", '%', 'q', 'myself', 'yourself', 'be', '"', 'any', "'s", 'which', 'why', '|', '~', 'too', 'mustn', '=', 'on', 'should', '-', "won't", ',', '*', 'rt', 'after', 'don', 'hasn', 'but', "hasn't", 'such', 'amp', '\\', 'only', 'until', 'whom', 'through', ':', '_', 'hers', 'by', "should've", 'below', 'with', 'out', 'd', 'into', 'will', 'an', 'under', 'i', '...', ']', 'll', ';', "that'll", "needn't", 'http', 'than', 'more', 'most', "aren't", 'about', '?', "wouldn't", 'no', 'down', 'now', 'yourselves', 'his', 'doing', 'it', "wasn't", 'ma', 'not', '>', 'those', 'has'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# flattening/simplifying all the tokens in the dataframe to one list
all_tokens = [word.lower() for tokens in data_exp['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
token_freq = Counter(all_tokens)

# most used tokens
most_common_tokens = token_freq.most_common(30)

# creating a dataframe with the token frequency
token_df = pd.DataFrame(most_common_tokens, columns=['Token','Frequency'])

# display
for word, count in most_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 26335
# change: 25531
# global: 9227
# warming: 8749
# trump: 2872
# believe: 2257
# real: 1685
# people: 1494
# world: 1405
# us: 1325
# going: 1272
# like: 1223
# new: 960
# fight: 905
# think: 889
# science: 876
# via: 822
# need: 814
# hoax: 800
# know: 736
# die: 728
# say: 711
# scientists: 657
# weather: 640
# realdonaldtrump: 634
# time: 629
# epa: 622
# could: 614
# right: 613
# stop: 610

# %%
# one plot with all the top 30 words

plot1 = sns.barplot(
    x = 'Token',
    y = 'Frequency',
    data = token_df,
    hue = 'Token'
)
plot1.set_xticklabels(plot1.get_xticklabels(), rotation = 50,
                      horizontalalignment = 'right',
                      fontsize = 10)
plt.title('Most Frequently Used Words')
plt.show()
# Out:
# <ipython-input-8-362fe2ae52f7>:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot1.set_xticklabels(plot1.get_xticklabels(), rotation = 50,

# %%
# making smaller data frame with top ten

all_tokens = [word.lower() for tokens in data_exp['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]
# counting token frequency
token_freq = Counter(all_tokens)
# top ten used tokens
top_ten_tokens = token_freq.most_common(10)
# creating a dataframe with only the top tokens
top_ten_token_df = pd.DataFrame(top_ten_tokens, columns=['Token','Frequency'])


# another plot, this one with the top ten words
plot2 = sns.barplot(
    x = 'Token',
    y = 'Frequency',
    data = top_ten_token_df,
    hue = 'Token'
)
plot2.set_xticklabels(plot2.get_xticklabels(), rotation = 50,
                      horizontalalignment = 'right',
                      fontsize = 10)
plt.title('Top Ten Frequently Used Words')
plt.show()
# Out:
# <ipython-input-9-a01424738f92>:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot2.set_xticklabels(plot2.get_xticklabels(), rotation = 50,

# %%
# some analysis of trump-specific mentions

token_df.head(30)
# Out:
#               Token  Frequency
# 0           climate      26335
# 1            change      25531
# 2            global       9227
# 3           warming       8749
# 4             trump       2872
# 5           believe       2257
# 6              real       1685
# 7            people       1494
# 8             world       1405
# 9                us       1325
# 10            going       1272
# 11             like       1223
# 12              new        960
# 13            fight        905
# 14            think        889
# 15          science        876
# 16              via        822
# 17             need        814
# 18             hoax        800
# 19             know        736
# 20              die        728
# 21              say        711
# 22       scientists        657
# 23          weather        640
# 24  realdonaldtrump        634
# 25             time        629
# 26              epa        622
# 27            could        614
# 28            right        613
# 29             stop        610

# %%
# creating a pie chart comparing trump mentions to overall mentions

total_frequency = token_df['Frequency'].sum()

labels = ['Trump_Mentions', 'Remaining_Words']
numbers = 3506, total_frequency - 3506

colors = ['#ff9999', '#66b3ff',]

plt.pie (numbers, labels = labels, autopct = '%1.1f%%', startangle = 140, colors = colors)
plt.axis('equal')
plt.title('Trump Mentions vs Total Words')
plt.show()
