# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS4002-Group13/blob/main/TwitterCCData_VH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cloning Git Location
! git clone https://github.com/vrhughes/DS4002-Group13
# Out:
# Cloning into 'DS4002-Group13'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 49 (delta 14), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 6.19 MiB | 4.89 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# Reading In The Data
data = pd.read_csv('/content/DS4002-Group13/Project 1/twitter_sentiment_data.csv')
data.head()

# data is a DataFrame (43943, 3)
# in the sentiment column 1 is pro/believes, -1 is anti/non-believer, 0 is neutral
# Out:
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#               tweetid
# 0  792927353886371840
# 1  793124211518832641
# 2  793124402388832256
# 3  793124635873275904
# 4  793125156185137153

# %%
# Basic Cleaning Of "data"

# 1. Deleting tweetid column
data.drop(['tweetid'], axis = 1, inplace = True)
print("Dropped tweetid column")
print(data.head())
# Out:
# Dropped tweetid column
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...

# %%
# Finding Most Frequently Used Words
import nltk
nltk.download('punkt_tab')

data['tokenized_tweet'] = data['message'].apply(nltk.word_tokenize)
data.head()

# the tokenized_tweet column contains series of tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#                                      tokenized_tweet
# 0  [@, tiniebeany, climate, change, is, an, inter...
# 1  [RT, @, NatGeoChannel, :, Watch, #, BeforeTheF...
# 2  [Fabulous, !, Leonardo, #, DiCaprio, 's, film,...
# 3  [RT, @, Mick_Fanning, :, Just, watched, this, ...
# 4  [RT, @, cnalive, :, Pranita, Biswasi, ,, a, Lu...

# %%
#
from collections import Counter
from nltk.corpus import stopwords
import string

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)

stop_words.update(list(string.punctuation))
print(stop_words)

tw_stopwords = ['rt', 'https', "'", "'s", "n't", "...", "…", 'http', "’", 'amp', 'would', 'one', 'q', 'you', 'make', "'m", "//t.co/sjofonã¢â‚¬â¦"]
incl_stop = stop_words.union(tw_stopwords)

excl_stop = {'against', "isn't", 'doesn', "don't", "shouldn't"}
new_stop = set([word for word in incl_stop if word not in excl_stop])

print(new_stop)
# Out:
# {'it', 'for', 'at', 'over', 'other', 've', 'about', "it's", 'you', 'both', 'his', 're', 'won', 'themselves', 'don', 'haven', 'ourselves', 'to', 'such', 'or', 'too', 'wouldn', 'me', 'hers', "weren't", 'wasn', 'more', "won't", 'mustn', 'itself', 'hasn', 'she', 'only', 'again', 'can', 'any', 'those', 'that', "that'll", 'during', 'these', 'under', 'my', 'of', "wouldn't", "you've", "you're", 'him', "mightn't", 'from', "you'd", 'but', 'no', 'why', 'have', 'as', 'will', 'needn', 'with', "doesn't", 'same', 'didn', "don't", 'all', 'now', "you'll", 'does', 'their', 'whom', 'having', 'up', 'he', 'there', 'than', "should've", "shan't", 'y', 's', "isn't", "wasn't", 'theirs', 'by', 'the', 'because', 'am', 'few', 'shouldn', 'be', 'hadn', "didn't", 'ours', 'a', 'being', 'do', 'its', "aren't", "couldn't", 'below', 'some', "mustn't", 'nor', 'did', 'between', 'out', 'against', 'very', "hasn't", 'them', 'should', 'this', 'before', 'above', 'after', 'how', 'when', 'yourselves', 'are', 'own', 'yours', 'doing', 'so', 'down', 'o', 'not', 'off', 'further', 'm', "hadn't", 'i', 'himself', 'on', 'her', "shouldn't", "she's", 'were', 'then', 'which', 'in', 'once', 'if', 'yourself', 'was', 'weren', 'doesn', 'ma', 'isn', 'where', 'until', 'couldn', 't', 'just', 'through', 'herself', 'is', 'had', 'what', 'your', 'an', 'here', 'been', 'into', 'll', 'ain', "needn't", 'has', 'aren', 'd', 'myself', 'we', "haven't", 'who', 'shan', 'they', 'and', 'most', 'mightn', 'our', 'each', 'while'}
# {'it', 'for', 'at', 'over', 'other', 've', 'about', "it's", 'you', 'both', 'his', 're', 'won', 'themselves', 'don', 'haven', 'ourselves', 'to', 'such', '+', '%', 'or', 'too', ']', 'wouldn', 'me', 'hers', '#', "weren't", '$', 'wasn', 'more', ';', "won't", 'mustn', 'itself', '>', 'hasn', 'she', 'only', '<', 'again', 'can', 'any', 'those', 'that', "that'll", '`', 'during', 'these', 'under', 'my', 'of', "wouldn't", "you've", "you're", 'him', "mightn't", 'from', "you'd", '-', 'but', 'no', 'why', 'have', 'as', 'will', 'needn', 'with', "doesn't", 'same', 'didn', '}', "don't", 'all', 'now', "you'll", 'does', 'their', 'whom', 'having', 'up', 'he', 'there', '^', 'than', "should've", "shan't", 'y', 's', "isn't", "wasn't", 'theirs', 'by', 'the', 'because', 'am', '\\', 'few', 'shouldn', ':', 'be', 'hadn', "didn't", 'ours', '|', 'a', 'being', 'do', 'its', "aren't", '=', "couldn't", 'below', 'some', "mustn't", 'nor', '*', '[', 'did', 'between', 'out', 'against', 'very', "hasn't", 'them', 'should', 'this', 'before', "'", 'above', 'after', '&', 'how', 'when', 'yourselves', 'are', 'own', '.', 'yours', 'doing', 'so', 'down', 'o', 'not', 'off', 'further', 'm', "hadn't", '"', 'i', 'himself', 'on', ')', 'her', "shouldn't", '~', '(', "she's", 'were', 'then', '/', ',', 'which', '{', 'in', 'once', 'if', 'yourself', 'was', '_', 'weren', 'doesn', 'ma', 'isn', 'where', 'until', 'couldn', '@', 't', 'just', 'through', 'herself', '?', 'is', 'had', 'what', 'your', 'an', 'here', 'been', 'into', 'll', 'ain', "needn't", 'has', 'aren', 'd', 'myself', 'we', "haven't", 'who', 'shan', 'they', '!', 'and', 'most', 'mightn', 'our', 'each', 'while'}
# {'it', 'for', '’', 'over', 'at', 'other', 've', 'about', "it's", 'you', 'both', 'his', 're', 'won', 'themselves', 'don', 'haven', 'ourselves', 'to', 'such', '+', '%', 'or', 'too', ']', 'wouldn', 'me', 'hers', '#', "'m", "weren't", '$', 'wasn', 'more', ';', "won't", 'mustn', 'itself', 'q', '>', 'hasn', 'she', 'only', '<', 'again', 'can', 'any', 'those', 'that', "that'll", '`', 'during', 'these', 'under', 'my', 'of', "wouldn't", "you've", "you're", 'him', "mightn't", 'from', "you'd", '-', 'but', 'no', 'why', 'have', 'as', 'will', 'needn', 'with', "doesn't", 'same', 'didn', '}', 'now', 'all', "you'll", 'does', 'their', 'whom', 'having', 'up', 'he', 'there', '^', 'than', "should've", "shan't", '…', 'y', 'while', 's', "wasn't", 'https', 'theirs', 'by', 'the', 'because', 'am', '\\', 'few', 'shouldn', ':', '...', 'be', 'hadn', "didn't", 'ours', 'make', '|', 'a', 'being', 'do', 'its', "aren't", '=', "couldn't", 'below', 'some', "mustn't", 'nor', '*', '[', 'did', 'between', 'out', 'very', "hasn't", 'them', 'should', 'this', 'before', "n't", 'one', 'amp', "'", 'above', 'after', '&', 'how', 'when', 'yourselves', 'are', 'own', '.', 'yours', 'doing', 'so', 'down', 'o', 'not', 'off', 'further', 'm', "hadn't", '"', 'i', 'himself', 'on', ')', 'her', '~', 'http', '(', "she's", 'were', 'then', '/', ',', 'which', '{', 'in', 'once', 'if', 'yourself', '//t.co/sjofonã¢â‚¬â¦', 'was', '_', 'weren', 'ma', 'isn', 'where', 'until', 'couldn', '@', 'rt', 't', 'just', 'through', 'herself', '?', "'s", 'is', 'had', 'what', 'your', 'an', 'here', 'been', 'into', 'll', 'ain', "needn't", 'would', 'has', 'aren', 'd', 'myself', 'we', "haven't", 'shan', 'they', '!', 'and', 'most', 'mightn', 'our', 'each', 'who'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# flattening/simplifying all the tokens in the dataframe to one list
all_tokens = [word.lower() for tokens in data['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
token_freq = Counter(all_tokens)

# most used tokens
most_common_tokens = token_freq.most_common(30)

# display
for word, count in most_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 34679
# change: 33521
# global: 10621
# warming: 9950
# trump: 4916
# believe: 2324
# us: 1789
# real: 1766
# world: 1763
# via: 1594
# people: 1583
# new: 1527
# going: 1313
# fight: 1303
# like: 1263
# says: 1187
# epa: 1181
# scientists: 1128
# science: 1104
# could: 978
# say: 934
# think: 924
# hoax: 876
# need: 844
# against: 794
# donald: 780
# president: 765
# time: 763
# know: 760
# news: 756

# %%
# Counting tokens in for sentiment 0
n = data['sentiment'].isin([0])
neutral_tweets = data[n]

# flattening/simplifying all the tokens in the dataframe to one list
neutral_tokens = [word.lower() for tokens in neutral_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
n_token_freq = Counter(neutral_tokens)

# most used tokens
n_common_tokens = n_token_freq.most_common(30)

# display
for word, count in n_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 4529
# change: 4462
# global: 3169
# warming: 3083
# trump: 464
# like: 310
# real: 287
# us: 256
# believe: 224
# think: 207
# people: 200
# said: 177
# new: 161
# world: 161
# know: 150
# penguin: 150
# get: 146
# says: 144
# cause: 141
# hot: 140
# weather: 132
# could: 128
# good: 126
# going: 126
# say: 123
# hoax: 121
# thing: 118
# really: 116
# via: 115
# need: 114

# %%
# Counting tokens in for sentiment 1
p = data['sentiment'].isin([1])
pro_tweets = data[p]

# flattening/simplifying all the tokens in the dataframe to one list
pro_tokens = [word.lower() for tokens in pro_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
p_token_freq = Counter(pro_tokens)

# most used tokens
p_common_tokens = p_token_freq.most_common(30)

# display
for word, count in p_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 19608
# change: 18876
# global: 4217
# warming: 3824
# trump: 2253
# believe: 1896
# real: 1233
# world: 1141
# people: 1128
# going: 1078
# us: 937
# fight: 828
# like: 782
# new: 717
# die: 674
# need: 657
# science: 603
# via: 601
# think: 594
# thinking: 565
# epa: 523
# husband: 518
# say: 515
# hoax: 512
# action: 507
# stephenschlegel: 507
# know: 489
# against: 484
# scientists: 469
# planet: 466

# %%
# Counting tokens in for sentiment -1
a = data['sentiment'].isin([-1])
anti_tweets = data[a]

# flattening/simplifying all the tokens in the dataframe to one list
anti_tokens = [word.lower() for tokens in anti_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
a_token_freq = Counter(anti_tokens)

# most used tokens
a_common_tokens = a_token_freq.most_common(30)

# display
for word, count in a_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 2198
# change: 2193
# warming: 1842
# global: 1841
# obama: 195
# realdonaldtrump: 174
# science: 174
# hoax: 167
# people: 166
# real: 165
# 'climate: 163
# trump: 155
# weather: 141
# believe: 137
# stevesgoddard: 135
# years: 132
# us: 132
# like: 131
# scam: 128
# man: 123
# gore: 123
# made: 120
# data: 115
# al: 108
# via: 106
# scientists: 105
# 'global: 103
# world: 103
# fake: 102
# know: 97

# %%
# Counting tokens in for sentiment 2
n = data['sentiment'].isin([2])
news_tweets = data[n]

# flattening/simplifying all the tokens in the dataframe to one list
news_tokens = [word.lower() for tokens in news_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
news_token_freq = Counter(news_tokens)

# most used tokens
news_common_tokens = news_token_freq.most_common(30)

# display
for word, count in news_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 8344
# change: 7990
# trump: 2044
# global: 1394
# warming: 1201
# via: 772
# says: 642
# new: 567
# epa: 559
# scientists: 471
# us: 464
# fight: 398
# study: 392
# could: 364
# world: 358
# news: 348
# china: 330
# obama: 320
# paris: 312
# ‘: 279
# donald: 277
# report: 260
# pruitt: 257
# may: 254
# energy: 232
# science: 228
# scott: 228
# say: 223
# thehill: 219
# against: 216

# %% [markdown]
# do percentage comparison of tokens across 3 categories

# %%
# creating a pie chart comparing trump mentions to overall mentions

total_frequency = token_df['Frequency'].sum()

labels = ['Trump_Mentions', 'Remaining_Words']
numbers = 3506, total_frequency - 3506

colors = ['#ff9999', '#66b3ff',]

plt.pie (numbers, labels = labels, autopct = '%1.1f%%', startangle = 140, colors = colors)
plt.axis('equal')
plt.title('Trump Mentions vs Total Words')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f0d6c6af8647> in <cell line: 0>()
#       1 # creating a pie chart comparing trump mentions to overall mentions
#       2
# ----> 3 total_frequency = token_df['Frequency'].sum()
#       4
#       5 labels = ['Trump_Mentions', 'Remaining_Words']
#
# NameError: name 'token_df' is not defined
