# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS4002-Group13/blob/main/TwitterCCData_VH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cloning Git Location
! git clone https://github.com/vrhughes/DS4002-Group13
# Out:
# Cloning into 'DS4002-Group13'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 35 (delta 7), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 5.11 MiB | 8.34 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# Reading In The Data
data = pd.read_csv('/content/DS4002-Group13/Project 1/twitter_sentiment_data.csv')
data.head()

# data is a DataFrame (43943, 3)
# in the sentiment column 1 is pro/believes, -1 is anti/non-believer, 0 is neutral
# Out:
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#               tweetid
# 0  792927353886371840
# 1  793124211518832641
# 2  793124402388832256
# 3  793124635873275904
# 4  793125156185137153

# %%
# Basic Cleaning Of "data"

# 1. Deleting tweetid column
data.drop(['tweetid'], axis = 1, inplace = True)
print("Dropped tweetid column")
print(data.head())

# 2. Getting rid of sentiment rows with value of 2(they're news sites not users)
data = data.drop(data[data['sentiment'] == 2].index)
print("Dropped sentiment rows with value of 2")
print(data.head())

# data is still a DataFrame, new dimensions (34667, 2)
# Out:
# Dropped tweetid column
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
# Dropped sentiment rows with value of 2
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...

# %%
# Finding Most Frequently Used Words
import nltk
nltk.download('punkt_tab')

data_exp = data.copy()

data_exp['tokenized_tweet'] = data_exp['message'].apply(nltk.word_tokenize)
data_exp.head()

# the tokenized_tweet column contains series of tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...
#
#                                      tokenized_tweet
# 0  [@, tiniebeany, climate, change, is, an, inter...
# 1  [RT, @, NatGeoChannel, :, Watch, #, BeforeTheF...
# 2  [Fabulous, !, Leonardo, #, DiCaprio, 's, film,...
# 3  [RT, @, Mick_Fanning, :, Just, watched, this, ...
# 5  [Unamshow, awache, kujinga, na, iko, global, w...

# %%
#
from collections import Counter
from nltk.corpus import stopwords
import string

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)

stop_words.update(list(string.punctuation))
print(stop_words)

tw_stopwords = ['rt', 'https', "'", "'s", "n't", "...", "…", 'http', "’", 'amp', 'would', 'one', 'q', 'you', 'make', "'m", "//t.co/sjofonã¢â‚¬â¦"]
incl_stop = stop_words.union(tw_stopwords)

excl_stop = {'against', "isn't", 'doesn', "don't", "shouldn't"}
new_stop = set([word for word in incl_stop if word not in excl_stop])

print(new_stop)
# Out:
# {'can', 'most', 'as', 'nor', 'been', 'i', 'here', 'any', 'then', 'didn', 'hasn', "shan't", 'his', 'myself', 'mightn', 'only', 'ours', 't', "it's", 'o', 'has', 'after', 'this', 'do', 'm', 'these', 'yours', "you've", 'whom', 'below', "doesn't", "weren't", "wouldn't", 'me', 'will', 'hadn', 'won', 'such', "won't", 'does', 've', 'both', 'd', 'am', 'other', 'she', 'down', 'under', 'up', 'll', 'shouldn', 'out', 'how', 'over', 'but', 'ma', 'in', 'a', 'from', 'isn', 'now', 'own', 'that', 'being', 'needn', 'above', "needn't", "mustn't", 'where', 'few', 'which', 'or', 'when', 'they', 'because', "should've", 'you', 'to', "you'll", 'the', 'theirs', 'don', 'further', 'an', 'not', "didn't", 'did', 'more', 'my', 'we', 'some', 'very', 'its', 'no', 'between', "you'd", 'her', 'before', 'couldn', 're', 'yourself', 'through', "couldn't", 'ourselves', "wasn't", 'off', 'with', 'same', 'again', 'doesn', 'are', 'until', 'should', 'ain', 'wasn', "you're", "she's", "mightn't", "aren't", 'who', 'your', 'at', "don't", 'against', 'themselves', 'than', 'what', 'so', 'our', 'too', "hasn't", 'haven', 'hers', 'having', 'once', 'himself', 'y', 'shan', 'he', 'why', 'yourselves', 'each', "hadn't", 'into', 'for', "haven't", "shouldn't", "isn't", 'him', 'weren', 'wouldn', 'of', 'herself', 'those', 'during', 'about', 'on', "that'll", 'aren', 'them', 'all', 'have', 'doing', 'and', 'had', 'mustn', 'itself', 'it', 'while', 'just', 's', 'be', 'there', 'by', 'their', 'were', 'was', 'if', 'is'}
# {'can', 'most', '{', 'as', '$', '\\', '^', 'nor', 'been', 'i', 'here', 'any', 'then', 'didn', '%', 'hasn', "shan't", 'his', 'myself', 'mightn', 'only', 'ours', 't', '@', "it's", 'o', 'has', 'after', '#', 'this', 'do', 'm', 'these', 'yours', "you've", 'whom', 'below', "doesn't", "weren't", "wouldn't", 'me', 'will', 'hadn', 'won', "'", 'such', "won't", 'does', 've', 'both', 'd', 'am', 'other', 'she', 'down', 'under', 'up', 'll', ':', 'shouldn', 'out', 'how', 'over', 'but', 'ma', 'in', 'a', 'from', 'isn', 'now', '&', 'own', '/', 'that', 'being', 'needn', 'above', "needn't", "mustn't", '~', '-', 'where', 'few', 'which', 'or', 'when', 'they', 'because', "should've", 'you', 'to', '|', "you'll", 'the', '*', '`', 'theirs', 'don', 'further', 'an', 'not', "didn't", 'did', 'more', '+', 'my', 'we', 'some', 'very', 'its', 'no', 'between', "you'd", 'her', '=', 'before', 'couldn', 're', 'yourself', 'through', "couldn't", 'ourselves', "wasn't", 'off', 'with', 'same', 'again', 'doesn', '"', '(', 'are', 'until', 'should', 'ain', 'wasn', '_', "you're", "she's", "mightn't", "aren't", '}', '!', 'who', 'your', 'at', "don't", 'against', 'themselves', 'than', 'what', 'so', 'our', 'too', "hasn't", 'haven', 'hers', 'having', 'once', '[', 'himself', 'y', '.', 'shan', 'he', 'why', 'yourselves', 'each', "hadn't", 'into', 'for', "haven't", "shouldn't", "isn't", 'him', 'weren', ',', 'wouldn', '?', 'of', 'herself', 'those', '<', 'during', 'about', 'on', "that'll", 'aren', 'them', 'all', 'have', 'doing', 'and', 'had', 'mustn', ']', 'itself', 'it', '>', 'while', 'just', 's', 'be', 'there', 'by', 'their', ')', 'were', ';', 'was', 'if', 'is'}
# {'can', 'most', '{', 'as', '$', '\\', '^', 'nor', 'if', 'been', 'i', 'here', 'any', 'then', 'didn', '%', 'hasn', "shan't", "n't", 'his', 'myself', 'mightn', 'only', 'ours', 't', '@', "it's", 'o', 'has', 'after', '#', 'this', 'do', 'm', 'these', 'yours', "you've", 'whom', "doesn't", "weren't", "wouldn't", 'me', 'make', 'will', 'hadn', 'won', 'http', "'", 'such', "won't", 'does', 'was', 've', '’', 'both', 'd', 'am', 'other', 'she', 'down', 'under', 'up', 'll', ':', 'shouldn', 'out', 'how', 'over', 'but', 'ma', 'in', 'a', 'from', 'isn', 'now', '&', 'own', '/', 'that', 'being', 'needn', 'above', "needn't", "mustn't", '~', "'s", '//t.co/sjofonã¢â‚¬â¦', '-', 'where', 'few', 'which', 'or', 'when', 'they', 'because', "should've", 'you', 'to', '|', "you'll", 'the', '*', '`', 'theirs', 'don', 'further', 'an', 'not', "didn't", 'did', 'more', '+', 'my', 'we', 'some', 'very', 'its', 'no', 'between', "you'd", 'her', '=', 'before', 'rt', 'couldn', 're', 'yourself', 'through', "couldn't", 'ourselves', "wasn't", 'off', 'with', 'same', 'again', '"', '(', 'are', 'until', 'should', 'ain', 'wasn', "you're", "she's", "mightn't", "aren't", '}', 'q', '!', 'who', 'your', 'at', 'would', 'amp', 'themselves', 'than', 'what', 'so', 'our', 'too', "hasn't", 'haven', 'hers', 'having', 'once', '[', 'himself', 'y', "'m", '.', 'shan', 'he', 'why', '...', 'yourselves', 'each', "hadn't", 'into', 'for', "haven't", 'him', 'weren', ',', 'wouldn', '?', 'of', 'herself', 'those', '<', 'during', 'about', 'on', "that'll", 'aren', 'them', 'all', 'https', 'have', 'doing', 'and', 'had', 'mustn', 'were', ']', 'itself', 'it', '>', '…', 'while', 'just', 's', 'be', 'there', 'by', 'their', ')', 'below', ';', '_', 'one', 'is'}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# flattening/simplifying all the tokens in the dataframe to one list
all_tokens = [word.lower() for tokens in data_exp['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
token_freq = Counter(all_tokens)

# most used tokens
most_common_tokens = token_freq.most_common(30)

# display
for word, count in most_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 26335
# change: 25531
# global: 9227
# warming: 8749
# trump: 2872
# believe: 2257
# real: 1685
# people: 1494
# world: 1405
# us: 1325
# going: 1272
# like: 1223
# new: 960
# fight: 905
# think: 889
# science: 876
# via: 822
# need: 814
# hoax: 800
# know: 736
# die: 728
# say: 711
# scientists: 657
# weather: 640
# realdonaldtrump: 634
# time: 629
# epa: 622
# could: 614
# right: 613
# stop: 610

# %%
# Counting tokens in for sentiment 0
n = data_exp['sentiment'].isin([0])
neutral_tweets = data_exp[n]

# flattening/simplifying all the tokens in the dataframe to one list
neutral_tokens = [word.lower() for tokens in neutral_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
n_token_freq = Counter(neutral_tokens)

# most used tokens
n_common_tokens = n_token_freq.most_common(30)

# display
for word, count in n_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 4529
# change: 4462
# global: 3169
# warming: 3083
# trump: 464
# like: 310
# real: 287
# us: 256
# believe: 224
# think: 207
# people: 200
# said: 177
# new: 161
# world: 161
# know: 150
# penguin: 150
# get: 146
# says: 144
# cause: 141
# hot: 140
# weather: 132
# could: 128
# good: 126
# going: 126
# say: 123
# hoax: 121
# thing: 118
# really: 116
# via: 115
# need: 114

# %%
# Counting tokens in for sentiment 1
p = data_exp['sentiment'].isin([1])
pro_tweets = data_exp[p]

# flattening/simplifying all the tokens in the dataframe to one list
pro_tokens = [word.lower() for tokens in pro_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
p_token_freq = Counter(pro_tokens)

# most used tokens
p_common_tokens = p_token_freq.most_common(30)

# display
for word, count in p_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 19608
# change: 18876
# global: 4217
# warming: 3824
# trump: 2253
# believe: 1896
# real: 1233
# world: 1141
# people: 1128
# going: 1078
# us: 937
# fight: 828
# like: 782
# new: 717
# die: 674
# need: 657
# science: 603
# via: 601
# think: 594
# thinking: 565
# epa: 523
# husband: 518
# say: 515
# hoax: 512
# action: 507
# stephenschlegel: 507
# know: 489
# against: 484
# scientists: 469
# planet: 466

# %%
# Counting tokens in for sentiment -1
a = data_exp['sentiment'].isin([-1])
anti_tweets = data_exp[a]

# flattening/simplifying all the tokens in the dataframe to one list
anti_tokens = [word.lower() for tokens in anti_tweets['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
a_token_freq = Counter(anti_tokens)

# most used tokens
a_common_tokens = a_token_freq.most_common(30)

# display
for word, count in a_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 2198
# change: 2193
# warming: 1842
# global: 1841
# obama: 195
# realdonaldtrump: 174
# science: 174
# hoax: 167
# people: 166
# real: 165
# 'climate: 163
# trump: 155
# weather: 141
# believe: 137
# stevesgoddard: 135
# years: 132
# us: 132
# like: 131
# scam: 128
# man: 123
# gore: 123
# made: 120
# data: 115
# al: 108
# via: 106
# scientists: 105
# 'global: 103
# world: 103
# fake: 102
# know: 97
