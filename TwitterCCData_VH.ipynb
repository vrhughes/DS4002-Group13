# %% [markdown]
# <a href="https://colab.research.google.com/github/vrhughes/DS4002-Group13/blob/main/TwitterCCData_VH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Necessary Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cloning Git Location
! git clone https://github.com/vrhughes/DS4002-Group13
# Out:
# Cloning into 'DS4002-Group13'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 23 (delta 1), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 4.91 MiB | 12.47 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# Reading In The Data
data = pd.read_csv('/content/DS4002-Group13/Project 1/twitter_sentiment_data.csv')
data.head()

# data is a DataFrame (43943, 3)
# in the sentiment column 1 is pro/believes, -1 is anti/non-believer, 0 is neutral
# Out:
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#               tweetid
# 0  792927353886371840
# 1  793124211518832641
# 2  793124402388832256
# 3  793124635873275904
# 4  793125156185137153

# %%
# Basic Cleaning Of "data"

# 1. Deleting tweetid column
data.drop(['tweetid'], axis = 1, inplace = True)
print("Dropped tweetid column")
print(data.head())

# 2. Getting rid of sentiment rows with value of 2(they're news sites not users)
data = data.drop(data[data['sentiment'] == 2].index)
print("Dropped sentiment rows with value of 2")
print(data.head())

# data is still a DataFrame, new dimensions (34667, 2)
# Out:
# Dropped tweetid column
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
# Dropped sentiment rows with value of 2
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...

# %%
# Finding Most Frequently Used Words
import nltk
nltk.download('punkt_tab')

data_exp = data.copy()

data_exp['tokenized_tweet'] = data_exp['message'].apply(nltk.word_tokenize)
data_exp.head()

# the tokenized_tweet column contains series of tokens
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
#    sentiment                                            message  \
# 0         -1  @tiniebeany climate change is an interesting h...
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 5          0  Unamshow awache kujinga na iko global warming ...
#
#                                      tokenized_tweet
# 0  [@, tiniebeany, climate, change, is, an, inter...
# 1  [RT, @, NatGeoChannel, :, Watch, #, BeforeTheF...
# 2  [Fabulous, !, Leonardo, #, DiCaprio, 's, film,...
# 3  [RT, @, Mick_Fanning, :, Just, watched, this, ...
# 5  [Unamshow, awache, kujinga, na, iko, global, w...

# %%
#
from collections import Counter
from nltk.corpus import stopwords
import string

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
print(stop_words)

stop_words.update(list(string.punctuation))
print(stop_words)

tw_stopwords = ['rt', 'https', "'", "'s", "n't", "...", "…", 'http', "’", 'amp', 'would', 'one', 'q', 'you', 'make']
incl_stop = stop_words.union(tw_stopwords)

excl_stop = {'against', "isn't", 'doesn', "don't", "i", 'you', "shouldn't"}
new_stop = set([word for word in incl_stop if word not in excl_stop])

print(new_stop)
# Out:
# {'couldn', 'has', "shan't", "haven't", 'ourselves', 'such', 'what', 'don', 'than', "wasn't", 'under', 'only', 'until', 'ours', 'when', 'where', 'between', "couldn't", 'again', 'can', 'because', 'haven', 'shouldn', 'itself', 'if', 'up', 'isn', 'while', 're', 'above', 'during', 'why', 'been', 'there', "doesn't", 'is', 'further', "didn't", 'at', "wouldn't", 'he', 'be', 'won', 'him', 've', 'himself', 'them', 'was', 'too', 'through', 'its', "you've", 'had', 'then', "it's", 'my', "mightn't", 'how', 'have', "aren't", 'each', "you'll", 'so', 'of', 'just', 'after', 'own', 'by', "needn't", 'did', 't', 'mightn', 'some', 'those', 'very', "you'd", 'these', 'both', 'this', 'are', 'theirs', 'will', 'themselves', 'didn', "you're", 'd', 'ain', 'were', 'hers', 'for', 'down', 'hadn', 'm', 'in', 'into', 'more', 'against', 'she', 'yourself', 'the', 'shan', 'or', 'to', 'all', 'no', 'before', "she's", "isn't", 'hasn', 'doing', 'weren', 'me', 'off', 'any', 'their', 'being', 'your', "won't", 'doesn', 'his', 'mustn', 'and', "hasn't", "weren't", 'her', 'as', 'which', 'wouldn', "mustn't", 'do', 'on', 'few', 'they', 'myself', 'once', 'over', 'that', "don't", 'not', 'herself', 'i', 'who', 'll', 'ma', 'most', 'from', 'o', 'y', 'wasn', 'yourselves', 'about', 'but', 'now', 'you', 'yours', 'having', 'same', 'should', 'aren', 'whom', 'am', 'with', "should've", 'out', 'an', 'does', 'a', "shouldn't", 'it', 'below', 'other', "hadn't", 'needn', 'we', 'here', 'our', 'nor', 's', "that'll"}
# {'couldn', 'has', "shan't", "haven't", '?', 'ourselves', 'such', 'what', 'don', 'than', "wasn't", '#', 'under', 'only', 'until', 'ours', '%', 'when', 'where', 'between', "couldn't", 'again', 'can', 'because', 'haven', 'shouldn', 'itself', 'if', 'up', 'isn', 'while', 're', 'above', 'during', 'why', 'been', 'there', "doesn't", '-', 'is', 'further', "didn't", 'at', "wouldn't", '^', 'he', '&', 'be', 'won', 'him', 've', 'himself', 'them', 'was', 'too', 'through', 'its', "you've", '/', 'had', 'then', ';', "it's", 'my', "mightn't", '$', 'how', 'have', "aren't", 'each', "you'll", 'so', 'of', 'just', 'after', 'own', 'by', "needn't", ')', 'did', 't', 'mightn', 'some', 'those', 'very', "you'd", 'these', '(', 'both', 'this', 'are', '|', 'theirs', 'will', 'themselves', 'didn', "you're", '@', 'd', 'ain', 'were', 'hers', 'for', 'down', 'hadn', 'm', 'in', 'into', 'more', 'against', 'she', 'yourself', 'the', '~', '+', '}', 'shan', 'or', 'to', '>', '=', ',', 'all', '"', ']', 'no', 'before', "she's", "isn't", 'hasn', 'doing', 'weren', 'me', "'", 'off', 'any', 'their', 'being', 'your', "won't", 'doesn', '!', 'his', 'mustn', 'and', "hasn't", "weren't", 'her', 'as', 'which', 'wouldn', "mustn't", 'do', 'on', 'few', 'they', 'myself', 'once', 'over', 'that', "don't", '[', 'not', 'herself', 'i', 'who', 'll', 'ma', 'most', 'from', 'o', ':', 'y', 'wasn', 'yourselves', '*', 'about', 'but', 'now', 'you', 'yours', 'having', 'same', 'should', 'aren', '<', 'whom', 'am', 'with', "should've", 'out', 'an', 'does', 'a', '{', "shouldn't", 'it', 'below', 'other', '\\', '.', "hadn't", 'needn', 'we', '_', 'here', 'our', 'nor', 's', '`', "that'll"}
# {'couldn', 'has', "shan't", "haven't", '?', 'ourselves', 'such', 'what', "n't", 'don', 'q', 'than', "wasn't", '#', 'under', 'only', 'http', 'until', 'ours', '%', 'when', 'where', 'between', "couldn't", 'again', 'can', 'because', 'haven', 'shouldn', 'itself', 'if', 'up', 'isn', 'while', 're', 'above', 'during', 'why', 'been', 'there', "doesn't", '-', 'is', 'further', "didn't", 'at', "wouldn't", '^', 'he', '&', 'be', 'would', 'won', 'him', 've', 'himself', '/', 'them', 'too', 'through', 'its', "you've", 'was', 'had', 'then', ';', 'one', "it's", 'my', "mightn't", '$', 'how', 'have', "aren't", 'each', "you'll", 'so', 'of', 'just', 'after', 'own', "'s", 'by', "needn't", ')', 'did', 't', '…', 'mightn', 'some', 'those', 'very', "you'd", 'these', '(', 'both', 'this', 'are', '|', 'theirs', 'will', 'themselves', 'didn', "you're", '@', 'd', 'ain', 'were', 'hers', 'for', 'down', 'hadn', 'm', 'in', 'into', 'more', 'she', 'yourself', 'the', '~', '+', '}', 'shan', '...', 'or', 'to', '>', '=', ',', 'all', '"', ']', 'no', 'before', "she's", 'hasn', 'doing', 'weren', 'me', "'", 'off', 'any', 'amp', 'their', 'being', 'your', "won't", '!', 'his', 'mustn', 'and', "hasn't", "weren't", 'her', 'as', 'which', 'wouldn', "mustn't", 'do', 'on', 'few', 'they', 'myself', 'once', 'over', 'that', '[', 'make', 'not', 'https', 'herself', 'who', 'll', 'ma', 'most', 'from', 'o', 'rt', ':', 'y', 'wasn', 'yourselves', '*', 'about', 'but', 'now', 'having', 'yours', 'same', 'should', 'aren', '<', '’', 'whom', 'am', 'with', "should've", 'out', 'an', 'does', 'a', '{', 'it', 'below', 'other', '\\', '.', "hadn't", 'needn', 'we', '_', 'here', 'our', 'nor', 's', '`', "that'll"}
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# flattening/simplifying all the tokens in the dataframe to one list
all_tokens = [word.lower() for tokens in data_exp['tokenized_tweet'] for word in tokens if word.lower() not in new_stop]

# counting the frequency
token_freq = Counter(all_tokens)

# most used tokens
most_common_tokens = token_freq.most_common(30)

# display
for word, count in most_common_tokens:
    print(f"{word}: {count}")
# Out:
# climate: 26335
# change: 25531
# global: 9227
# warming: 8749
# you: 3987
# i: 3826
# trump: 2872
# believe: 2257
# real: 1685
# people: 1494
# world: 1405
# us: 1325
# going: 1272
# like: 1223
# new: 960
# fight: 905
# think: 889
# science: 876
# via: 822
# need: 814
# hoax: 800
# know: 736
# die: 728
# say: 711
# scientists: 657
# weather: 640
# realdonaldtrump: 634
# time: 629
# epa: 622
# could: 614
